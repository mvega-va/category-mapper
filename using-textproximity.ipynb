# %%
# !pip install openai pandas numpy scipy

import time
import traceback

import numpy as np
import openai
import pandas as pd
from scipy.spatial.distance import cosine
import heapq
import os

openai.api_key = os.environ['OPENAI_API_KEY']
# Out:
# Looking in indexes: https://mvega:****@vdevtools.appspot.com/vpm/simple/
# Requirement already satisfied: openai in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (0.28.1)
# Requirement already satisfied: pandas in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (2.1.2)
# Requirement already satisfied: numpy in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (1.26.1)
# Requirement already satisfied: scipy in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (1.11.3)
# Requirement already satisfied: tqdm in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from openai) (4.66.1)
# Requirement already satisfied: requests>=2.20 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from openai) (2.31.0)
# Requirement already satisfied: aiohttp in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from openai) (3.8.6)
# Requirement already satisfied: tzdata>=2022.1 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from requests>=2.20->openai) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from requests>=2.20->openai) (3.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/maxvega/Documents/pythonProject1/venv/lib/python3.9/site-packages (from aiohttp->openai) (6.0.4)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
model = "text-embedding-ada-002"
def generate_embeddings(input):
    if pd.isna(input): return
    try:
        print(f"Category Embedding {input}")
        return np.array(openai.Embedding.create(
            engine=model,
            input=input.upper(),
            temperature=0,
            max_tokens=1024,
        )['data'][0]['embedding'])
    except openai.error.RateLimitError:
        print("Rate limiting...")
        time.sleep(60)
        return generate_embeddings(input)
    except:
        print(traceback.format_exc())
        time.sleep(60)
        return generate_embeddings(input)

# %%
 def generate_embeddings_from_csv(vcat_csv, to_match_csv):
        try:
            vcat_df = pd.read_csv(vcat_csv, names=["id", "name"])
        
            to_match_cats_df = pd.read_csv(to_match_csv, names=["id", "name"])
        
            to_match_cats_embeddings = to_match_cats_df.apply(
                lambda row: generate_embeddings(f'{row["name"]}'), axis=1)
            to_match_cats_df["embedding"] = to_match_cats_embeddings
            
            vcat_embeddings = vcat_df.apply(
                lambda row: generate_embeddings(f'{row["name"]}'), axis=1)
            vcat_df["embedding"] = vcat_embeddings
        except pd.errors.ParserError as e:
            print(f"Error reading CSV file: {e}")
            return None, None
        return vcat_df, to_match_cats_df

# %%
class HeapObject:
    def __init__(self, score, category_id, category_name):
        self.score = score
        self.category_id = category_id
        self.category_name = category_name

    def __lt__(self, other):
        return self.score < other.score

class MaxHeap:
    def __init__(self):
        self.heap = []

    def add(self, obj):
        heapq.heappush(self.heap, obj)

    def get_max(self):
        return self.heap[0].score if self.heap else None

    def extract_max(self):
        return heapq.heappop(self.heap).score if self.heap else None

    def __str__(self):
        return str([obj.score for obj in self.heap])
    
    def get_top_values(self, n):
        top_values = []
        for _ in range(n):
            if self.heap:
                top_values.append(heapq.heappop(self.heap).score)
        return top_values
    
    def get_top_objects(self, n):
        return heapq.nlargest(n, self.heap)

# %%
def perfect_match(cat1, cat2):
    if cat1.upper() == cat2.upper():
        return True
    return False

def extract_last_substring(input_string):
    parts = input_string.split(" > ")
    if len(parts) > 1:
        return parts[-1]
    else:
        return input_string

def matcher(from_vector, to_vector):
    matches = {}
    matches_list = []

    for _, category1 in from_vector.iterrows():
        print(category1['name'])
        category1_embedding = category1.embedding
        matches[category1.id] = MaxHeap()
        
        specific_cat1 = extract_last_substring(category1['name'])

        for category2 in to_vector.itertuples(index=False):
            category2_embedding = category2.embedding
            similarity_score = cosine(category1_embedding, category2_embedding)
            
            specific_cat2 = extract_last_substring(category2.name)
            if perfect_match(specific_cat1, specific_cat2):
                matches[category1.id].add(HeapObject(1, category2.id, category2.name))
            matches[category1.id].add(HeapObject(1-similarity_score, category2.id, category2.name))
    
        top_matches = matches[category1.id].get_top_objects(3)
        for i, heap_obj in enumerate(top_matches):
            matches_list.append({
                "VCategory ID": category1['id'],
                "Match ID": heap_obj.category_id,
                "VCategory Name": category1['name'],
                "Match Name": heap_obj.category_name,
                "Match": i+1,
                "Similarity Score": heap_obj.score
            })
    matches_df = pd.DataFrame(matches_list)
    matches_df.to_csv("matches_output.csv", index=False)

# %%
[from_vector, to_vector] = generate_embeddings_from_csv("CATEGORIES-V_CATEGORY.csv", "DATA_AXLE_TO_ADD.csv")
# Out:
# Category Embedding Oilseed (except Soybean) Farming
# Category Embedding Dry Pea and Bean Farming
# Category Embedding Oilseed and Grain Combination Farming
# Category Embedding Sugar Beet Farming
# Category Embedding Hay Farming
# Category Embedding Peanut Farming
# Category Embedding Strawberry Farming
# Category Embedding Orange Groves
# Category Embedding Nursery and Tree Production
# Category Embedding Shellfish Farming
# Category Embedding Soil Preparation Planting & Cultivating
# Category Embedding Veterinary Services
# Category Embedding Landscape Architectural Services
# Category Embedding Other Marine Fishing
# Category Embedding Emergency Property Restoration
# Category Embedding Heavy & Civil Engineering Construction
# Category Embedding Foundation Structure & Building Exterior Contractors
# Category Embedding Building Finishing Contractors
# Category Embedding Meat Processing
# Category Embedding Nonchocolate Confectionery Manufacturing
# Category Embedding Roasted Nuts & Peanut Butter Manufacturing
# Category Embedding Bottled Water Manufacturing
# Category Embedding Tortilla Manufacturing
# Category Embedding Apparel Knitting Mills
# Category Embedding Fiber Yarn & Thread Mills
# Category Embedding Cut & Sew Apparel Contractors
# Category Embedding Cut & Sew Apparel-Except Contractors (Mfrs)
# Category Embedding Curtain & Linen Mills
# Category Embedding Cut Stock Resawing Lumber & Planing
# Category Embedding Wood Window & Door Manufacturing
# Category Embedding Wood Kitchen Cabinet & Countertop (Mfrs)
# Category Embedding Wood Preservation
# Category Embedding Showcase Partition Shelving & Locker (Mfrs)
# Category Embedding Plastics Packaging Film & Sheet (Mfrs)
# Category Embedding Greeting Card Publishers
# Category Embedding Support Activities for Printing
# Category Embedding Artificial & Synthetic Fibers & Filaments (Mfrs)
# Category Embedding Cyclic Crude Intermediate/Gum/Wood Chemical (Mfrs)
# Category Embedding Petrochemical Manufacturing
# Category Embedding Oils-Re-Refined (Mfrs)
# Category Embedding Polystyrene Foam Product (Mfrs)
# Category Embedding Urethane & Other Foam Product-Except Polystyrene (Mfrs)
# Category Embedding Flat Glass (Mfrs)
# Category Embedding Iron & Steel Mills & Ferroalloy (Mfrs)
# Category Embedding Secondary Smelting & Alloying-Aluminum
# Category Embedding Communication & Energy Wire (Mfrs)
# Category Embedding Aluminum Foundries-Except Die-Casting
# Category Embedding Nonferrous Metal Foundries-Except Die-Casting
# Category Embedding Cookware Cutlery & Flatware (Mfrs)
# Category Embedding Heavy Gauge Metal Tank (Mfrs)
# Category Embedding Industrial Mold (Mfrs)
# Category Embedding Sawmill Woodworking & Paper Machinery (Mfrs)
# Category Embedding Industrial Machinery (Mfrs)
# Category Embedding Motor Vehicle Gas Engine & Parts (Mfrs)
# Category Embedding Residential Electric Lighting Fixture (Mfrs)
# Category Embedding Printed Circuit-Electronic Assembly (Mfrs)
# Category Embedding Heavy Duty Truck (Mfrs)
# Category Embedding Railroad Rolling Stock (Mfrs)
# Category Embedding Photographic Film Paper Plate Chemical & Copy Toner (Mfrs)
# Category Embedding Jewelry & Silverware (Mfrs)
# Category Embedding Office Supplies-Ex Paper (Mfrs)
# Category Embedding Fabricated Metal Product (Mfrs)
# Category Embedding Doll Toy & Game (Mfrs)
# Category Embedding Short Line Railroads
# Category Embedding Mixed Mode Transit Systems
# Category Embedding Bus & Motor Vehicle Transit Systems
# Category Embedding Land Scenic & Sightseeing Transportation
# Category Embedding Used Household & Office Goods Moving
# Category Embedding Solid Waste Collection
# Category Embedding Waste Collection & Hauling
# Category Embedding General Freight Trucking Long-Distance
# Category Embedding Long-Distance Specialized Freight Trucking
# Category Embedding Local Specialized Freight Trucking
# Category Embedding Port & Harbor Operations
# Category Embedding Shipping Navigational Services
# Category Embedding Nonscheduled Passenger Air Transportation
# Category Embedding Specialty Nonscheduled Air Transportation
# Category Embedding Misc Road Transportation Support
# Category Embedding Support Activities for Transportation
# Category Embedding Wireless Telecommunications Carriers-Ex Satellite
# Category Embedding Wired Telecommunications Carriers
# Category Embedding Agents for Wireless Telecommunications Services
# Category Embedding Satellite Telecommunications
# Category Embedding Nuclear Electric Power Generation
# Category Embedding Solar Electric Power Generation
# Category Embedding Wind Electric Power Generation
# Category Embedding Geothermal Electric Power Generation
# Category Embedding Biomass Electric Power Generation
# Category Embedding Electric Bulk Power Transmission & Control
# Category Embedding Fossil Fuel Electric Power Generation
# Category Embedding Other Electric Power Generation
# Category Embedding Water Supply & Irrigation Systems
# Category Embedding Solid Waste Combustors & Incinerators
# Category Embedding Nonhazardous Waste Treatment & Disposal
# Category Embedding Materials Recovery Facilities
# Category Embedding Remediation Services
# Category Embedding Automobile & Other Motor Vehicle (Whls)
# Category Embedding Tire & Tube (Whls)
# Category Embedding Brick Stone & Related Const Material (Whls)
# Category Embedding Roofing Siding & Insulation Material (Whls)
# Category Embedding Building Material Dealers
# Category Embedding Computer & Peripheral Eqpt & Software (Whls)
# Category Embedding Medical/Dental/Hospital Eqpt & Supl (Whls)
# Category Embedding Household Appliances & Electronics (Whls)
# Category Embedding Plumbing & Heating Equipment & Supplies (Whls)
# Category Embedding Heating & Air-Cond Eqpt & Supplies (Whls)
# Category Embedding Farm/Garden Machinery & Eqpt (Whls)
# Category Embedding Toy & Hobby Goods & Supplies (Whls)
# Category Embedding Jewelry/Watch Precious Stone & Metal (Whls)
# Category Embedding Printing & Writing Paper (Whls)
# Category Embedding Stationery & Office Supplies (Whls)
# Category Embedding Piece Goods Notions & Other Dry Goods (Whls)
# Category Embedding Footwear (Whls)
# Category Embedding Grain & Field Bean (Whls)
# Category Embedding Wine & Distilled Alcoholic Beverage (Whls)
# Category Embedding Book Periodical & Newspaper (Whls)
# Category Embedding Flower/Nursery Stock/Florists' Supplies (Whls)
# Category Embedding Tobacco Product & Electronic Cigarette (Whls)
# Category Embedding Paint Varnish & Supplies (Whls)
# Category Embedding Paint & Wallpaper Retailers
# Category Embedding Garden Center & Farm Supply Retailers
# Category Embedding Grocers-Delicatessen
# Category Embedding Fish & Seafood Retailers
# Category Embedding Confectionery & Nut Retailers
# Category Embedding Baked Goods Off-site Retailers
# Category Embedding Snack & Nonalcoholic Beverage Bars
# Category Embedding Automobile Dealers-Hydrogen Cars-New
# Category Embedding Book Retailers & News Dealers
# Category Embedding Hobby Toy & Game Retailers
# Category Embedding Luggage & Leather Goods Retailers
# Category Embedding Sewing Needlework & Piece Goods Retailers
# Category Embedding Cannabis Dispensary
# Category Embedding ITM-Interactive Teller Machine
# Category Embedding Peer to Peer Payment Services
# Category Embedding Virtual Currency Brokering & Dealing Exchange Services
# Category Embedding Credit Card Issuing
# Category Embedding Credit Intermediation
# Category Embedding Sales Financing
# Category Embedding Virtual Currency Trading Exchange Clearinghouses
# Category Embedding Health & Welfare Funds
# Category Embedding Reinsurance Carriers
# Category Embedding Residential Property Managers
# Category Embedding Insurance Funds
# Category Embedding Recreational Goods Rental
# Category Embedding Personal & Household Goods Repair & Maintenance
# Category Embedding Personal Care Services NEC
# Category Embedding Home Health Equipment Rental
# Category Embedding Misc Consumer Goods Rental
# Category Embedding Professional Employer Organizations
# Category Embedding Virtual Currency Mining
# Category Embedding Truck Utility Trailer & RV Rental & Leasing
# Category Embedding Specialized Automotive Repair
# Category Embedding Teleproduction & Postproduction Services
# Category Embedding Agents & Managers-Artists Athletes Entertainers
# Category Embedding Theater Companies & Dinner Theaters
# Category Embedding Promoters of Events with Facilities
# Category Embedding Performing Arts Companies
# Category Embedding Spectator Sports
# Category Embedding Freestanding Ambulatory Surgical & Emergency Centers
# Category Embedding Family Planning Centers
# Category Embedding Rehabilitation Services
# Category Embedding Ambulatory Health Care Services
# Category Embedding Cosmetology & Barber Schools
# Category Embedding Fine Arts Schools
# Category Embedding Exam Preparation & Tutoring
# Category Embedding Miscellaneous Schools & Instruction
# Category Embedding Elderly & Disabled Person Services
# Category Embedding Voluntary Health Organizations
# Category Embedding Grantmaking & Giving Services
# Category Embedding Social Membership Organization
# Category Embedding Artificial Intelligence Research/Development
# Category Embedding Nanotechnology Research & Development
# Category Embedding Physical Engineering & Life Sciences Research & Development
# Category Embedding Social Sciences & Humanities Research & Development
# Category Embedding Testing Laboratories & Services
# Category Embedding Administrative & General Management Consulting Services
# Category Embedding Independent Artists Writers & Performers
# Category Embedding Government Executive Offices
# Category Embedding Executive & Legislative Offices Combined
# Category Embedding General Government Support
# Category Embedding Legal Counsel & Prosecution
# Category Embedding Correctional Institutions
# Category Embedding General Justice Public Order & Safety Activities
# Category Embedding Public Finance Activities
# Category Embedding Government Education Programs Administration
# Category Embedding Public Health Programs Administration
# Category Embedding Government Human Resource Programs Administration
# Category Embedding Veterans' Affairs Administration
# Category Embedding Air/Water Resource/Solid Waste Mgmt Programs Administration
# Category Embedding Government Conservation Programs Administration
# Category Embedding Government Housing Programs Administration
# Category Embedding Government Urban Planning/Community/Rural Development Administration
# Category Embedding Government Economic Programs Administration
# Category Embedding Government Regulation & Administration-Communication/Utilities
# Category Embedding Government Agricultural Marketing & Commodities Regulation
# Category Embedding Government Commercial Licensing & Inspection Regulation
# Category Embedding Space Research & Technology
# Category Embedding International Affairs
# Category Embedding Professional Services > Website designer
# Category Embedding Restaurants > Paisa restaurant
# Category Embedding Restaurants > Ikan bakar restaurant
# Category Embedding Shopping > Animal feed store
# Category Embedding Beauty & Spas > Seitai
# Category Embedding Nightlife > Bar tabac
# Category Embedding Professional Services > Marriage or relationship counselor
# Category Embedding Restaurants > Jamaican restaurant
# Category Embedding Shopping > Neon sign shop
# Category Embedding Shopping > Hunting and fishing store
# Category Embedding Shopping > Pet supply store
# Category Embedding Health & Medical > Occupational health service
# Category Embedding Restaurants > Cape Verdean restaurant
# Category Embedding Industrial Goods and Manufacturing > Thread supplier
# Category Embedding Industrial Goods and Manufacturing > Turf supplier
# Category Embedding Shopping > Wig shop
# Category Embedding Shopping > Baby clothing store
# Category Embedding Local Services > Horse rental service
# Category Embedding Beauty & Spas > Hair extensions supplier
# Category Embedding Education > Private university
# Category Embedding Shopping > Bird shop
# Category Embedding Restaurants > Shawarma restaurant
# Category Embedding Professional Services > Hydraulic engineer
# Category Embedding Local Services > Fingerprinting service
# Category Embedding Industrial Goods and Manufacturing > Mining equipment
# Category Embedding Religious Organizations > Abundant Life church
# Category Embedding Shopping > Meat wholesaler
# Category Embedding Restaurants > Crêperie
# Category Embedding Shopping > Flea market
# Category Embedding Real Estate > Housing society
# Category Embedding Industrial Goods and Manufacturing > Rice mill
# Category Embedding Shopping > Batik clothing store
# Category Embedding Arts & Entertainment > Amusement center
# Category Embedding Professional Services > Gas engineer
# Category Embedding Local Services > Equipment rental agency
# Category Embedding Industrial Goods and Manufacturing > Appliance parts supplier
# Category Embedding Shopping > Bubble tea store
# Category Embedding Shopping > Used office furniture store
# Category Embedding Restaurants > Pizza restaurant
# Category Embedding Professional Services > Detective
# Category Embedding Industrial Goods and Manufacturing > Clock watch maker
# Category Embedding Local Services > Self-storage facility
# Category Embedding Religious Organizations > Presbyterian church
# Category Embedding Education > Faculty of media and information science
# Category Embedding Financial Services > Payment terminal
# Category Embedding Education > Chinese language instructor
# Category Embedding Industrial Goods and Manufacturing > Egg supplier
# Category Embedding Industrial Goods and Manufacturing > Fiberglass supplier
# Category Embedding Health & Medical > Denture care center
# Category Embedding Industrial Goods and Manufacturing > Ceramic manufacturer
# Category Embedding Education > Technical school
# Category Embedding Restaurants > Teppanyaki restaurant
# Category Embedding Restaurants > Dumpling restaurant
# Category Embedding Health & Medical > Optometrist
# Category Embedding Local Services > Parapharmacy
# Category Embedding Public Services & Government > Halfway house
# Category Embedding Shopping > Buddhist supplies store
# Category Embedding Education > School lunch center
# Category Embedding Home Services > Electric utility company
# Category Embedding Home Services > Telecommunications contractor
# Category Embedding Professional Services > Embossing service
# Category Embedding Financial Services > Savings bank
# Category Embedding Education > Cooking school
# Category Embedding Local Services > Glass engraving service
# Category Embedding Nightlife > Lounge
# Category Embedding Education > Foreign exchange students organization
# Category Embedding Industrial Goods and Manufacturing > Air conditioning system supplier
# Category Embedding Arts & Entertainment > Dinner theater
# Category Embedding Industrial Goods and Manufacturing > Incense supplier
# Category Embedding Industrial Goods and Manufacturing > Portable toilet supplier
# Category Embedding Restaurants > Kerala restaurant
# Category Embedding Public Services & Government > Public defender's office
# Category Embedding Professional Services > District attorney
# Category Embedding Shopping > Religious goods store
# Category Embedding Professional Services > Family planning counselor
# Category Embedding Education > Gymnasium school
# Category Embedding Shopping > Dry fruit store
# Category Embedding Shopping > Law book store
# Category Embedding Automotive > Ferrari dealer
# Category Embedding Nightlife > Lesbian bar
# Category Embedding Local Services > Drug testing service
# Category Embedding Restaurants > Cendol restaurant
# Category Embedding Health & Medical > Specialized hospital
# Category Embedding Shopping > Electrical appliance wholesaler
# Category Embedding Arts & Entertainment > Mountaineering class
# Category Embedding Public Services & Government > Womens protection service
# Category Embedding Shopping > Golf shop
# Category Embedding Hotels & Travel > Whale watching tour agency
# Category Embedding Local Services > Homeopathic pharmacy
# Category Embedding Shopping > Used musical instrument store
# Category Embedding Professional Services > Graffiti removal service
# Category Embedding Religious Organizations > Baptist church
# Category Embedding Restaurants > Azerbaijani Restaurant
# Category Embedding Automotive > Auto air conditioning service
# Category Embedding Professional Services > Paralegal services provider
# Category Embedding Active Life > Racquetball club
# Category Embedding Health & Medical > Men's health physician
# Category Embedding Transportation > Transportation service
# Category Embedding Restaurants > Lithuanian restaurant
# Category Embedding Shopping > Needlework shop
# Category Embedding Shopping > Rare book store
# Category Embedding Shopping > Furniture repair shop
# Category Embedding Active Life > Handball court
# Category Embedding Beauty & Spas > Beauty salon
# Category Embedding Pets > Pet moving service
# Category Embedding Industrial Goods and Manufacturing > Textile exporter
# Category Embedding Health & Medical > Alcoholism treatment program
# Category Embedding Home Services > Hot tub repair service
# Category Embedding Arts & Entertainment > Cultural center
# Category Embedding Shopping > Refrigerator store
# Category Embedding Local Services > Gas company
# Category Embedding Real Estate > Real estate fair
# Category Embedding Education > Surf school
# Category Embedding Active Life > Stamp collectors club
# Category Embedding Industrial Goods and Manufacturing > Light bulb supplier
# Category Embedding Active Life > Miniature golf course
# Category Embedding Hotels & Travel > SCUBA tour agency
# Category Embedding Professional Services > Import export company
# Category Embedding Active Life > Bocce ball court
# Category Embedding Local Services > Bail bonds service
# Category Embedding Restaurants > Tex-Mex restaurant
# Category Embedding Active Life > Zoo
# Category Embedding Event Planning & Services > Video conferencing service
# Category Embedding Active Life > Squash club
# Category Embedding Transportation > Airline
# Category Embedding Shopping > Piano store
# Category Embedding Local Services > Storage facility
# Category Embedding Shopping > Cold cut store
# Category Embedding Shopping > Vegetable wholesale market
# Category Embedding Industrial Goods and Manufacturing > Cannery
# Category Embedding Shopping > Jewelry store
# Category Embedding Professional Services > Certified public accountant
# Category Embedding Shopping > Tea market place
# Category Embedding Restaurants > Anhui restaurant
# Category Embedding Education > Art school
# Category Embedding Mining & Agriculture > Organic farm
# Category Embedding Shopping > Internet shop
# Category Embedding Professional Services > Feng shui consultant
# Category Embedding Active Life > Prawn fishing
# Category Embedding Beauty & Spas > Eyelash salon
# Category Embedding Local Services > Coal exporter
# Category Embedding Automotive > Auto upholsterer
# Category Embedding Financial Services > Fund management company
# Category Embedding Local Services > Video camera repair service
# Category Embedding Nightlife > Espresso bar
# Category Embedding Industrial Goods and Manufacturing > Packaging machinery
# Category Embedding Professional Services > Sign shop
# Category Embedding Financial Services > Insurance agency
# Category Embedding Education > Institute of technology
# Category Embedding Mining & Agriculture > Nuclear power plant
# Category Embedding Industrial Goods and Manufacturing > Garment exporter
# Category Embedding Health & Medical > Midwife
# Category Embedding Active Life > Aerial sports center
# Category Embedding Health & Medical > Psychotherapist
# Category Embedding Public Services & Government > Student career counseling office
# Category Embedding Education > Bartending school
# Category Embedding Local Services > Condominium rental agency
# Category Embedding Education > Foreign languages program school
# Category Embedding Public Services & Government > Foster care service
# Category Embedding Shopping > Lock Store
# Category Embedding Industrial Goods and Manufacturing > Weir
# Category Embedding Health & Medical > Intensivist
# Category Embedding Local Services > Bicycle repair shop
# Category Embedding Public Services & Government > Military recruiting office
# Category Embedding Restaurants > Seychelles restaurant
# Category Embedding Shopping > Millwork shop
# Category Embedding Active Life > Indoor cycling
# Category Embedding Shopping > Market
# Category Embedding Local Services > Funeral director
# Category Embedding Restaurants > Western restaurant
# Category Embedding Restaurants > French steakhouse restaurant
# Category Embedding Health & Medical > Pediatric hematologist
# Category Embedding Health & Medical > Mfr
# Category Embedding Transportation > Road construction company
# Category Embedding Restaurants > Health food restaurant
# Category Embedding Shopping > Video store
# Category Embedding Professional Services > Steel erector
# Category Embedding Transportation > LPG conversion
# Category Embedding Industrial Goods and Manufacturing > Electrical equipment supplier
# Category Embedding Education > Kung fu school
# Category Embedding Industrial Goods and Manufacturing > Tobacco supplier
# Category Embedding Education > Computer training school
# Category Embedding Public Services & Government > Municipal Department Civil Defense
# Category Embedding Education > School for the visually impaired
# Category Embedding Health & Medical > Pediatric nephrologist
# Category Embedding Health & Medical > Retirement home
# Category Embedding Shopping > Trailer supply store
# Category Embedding Home Services > Laundry service
# Category Embedding Hotels & Travel > Tour operator
# Category Embedding Industrial Goods and Manufacturing > Coal supplier
# Category Embedding Industrial Goods and Manufacturing > Topsoil supplier
# Category Embedding Shopping > Sheet music store
# Category Embedding Pets > Dog walker
# Category Embedding Health & Medical > Family planning center
# Category Embedding Religious Organizations > Musalla
# Category Embedding Automotive > Volvo dealer
# Category Embedding Home Services > Heating contractor
# Category Embedding Local Services > Stereo repair service
# Category Embedding Active Life > Scout hall
# Category Embedding Food > Soup kitchen
# Category Embedding Arts & Entertainment > Ferris wheel
# Category Embedding Shopping > Traditional market
# Category Embedding Public Services & Government > Homeless service
# Category Embedding Shopping > Vegetable wholesaler
# Category Embedding Shopping > Hot tub store
# Category Embedding Public Services & Government > Probation office
# Category Embedding Industrial Goods and Manufacturing > Machine workshop
# Category Embedding Health & Medical > Dental implants periodontist
# Category Embedding Automotive > Land Rover dealer
# Category Embedding Automotive > Auto insurance agency
# Category Embedding Local Services > Electronics repair shop
# Category Embedding Local Services > Road construction machine repair service
# Category Embedding Religious Organizations > Quaker church
# Category Embedding Restaurants > Québécois restaurant
# Category Embedding Shopping > Cookie shop
# Category Embedding Active Life > Yoga retreat center
# Category Embedding Local Services > Labor union
# Category Embedding Local Services > Flower delivery
# Category Embedding Education > Middle school
# Category Embedding Shopping > Do-it-yourself shop
# Category Embedding Arts & Entertainment > Casino
# Category Embedding Shopping > Used clothing store
# Category Embedding Shopping > Music box store
# Category Embedding Education > Horse riding school
# Category Embedding Home Services > Gas installation service
# Category Embedding Professional Services > Telecommunications engineer
# Category Embedding Public Services & Government > State department of agricultural development
# Category Embedding Education > Sailing school
# Category Embedding Event Planning & Services > Arena
# Category Embedding Industrial Goods and Manufacturing > Furniture accessories supplier
# Category Embedding Professional Services > Goldsmith
# Category Embedding Public Services & Government > Housing utility company
# Category Embedding Health & Medical > Dental radiology
# Category Embedding Industrial Goods and Manufacturing > Rainwater tank supplier
# Category Embedding Industrial Goods and Manufacturing > Alcohol manufacturer
# Category Embedding Restaurants > Californian restaurant
# Category Embedding Religious Organizations > Anglican church
# Category Embedding Health & Medical > Fertility clinic
# Category Embedding Industrial Goods and Manufacturing > Barrel supplier
# Category Embedding Health & Medical > Nutritionist
# Category Embedding Professional Services > Executor
# Category Embedding Arts & Entertainment > Air force base
# Category Embedding Professional Services > Coppersmith
# Category Embedding Industrial Goods and Manufacturing > Energy supplier
# Category Embedding Industrial Goods and Manufacturing > Plywood supplier
# Category Embedding Active Life > Pony club
# Category Embedding Professional Services > Building design company
# Category Embedding Health & Medical > Children's hospital
# Category Embedding Industrial Goods and Manufacturing > Plant nursery
# Category Embedding Active Life > Karate club
# Category Embedding Health & Medical > Physician referral service
# Category Embedding Industrial Goods and Manufacturing > Spring supplier
# Category Embedding Industrial Goods and Manufacturing > Manufacturer
# Category Embedding Shopping > Chinaware store
# Category Embedding Home Services > Window installation service
# Category Embedding Local Services > Studying center
# Category Embedding Education > Child care agency
# Category Embedding Automotive > Chrysler dealer
# Category Embedding Active Life > Swimming facility
# Category Embedding Public Services & Government > State police
# Category Embedding Active Life > Sauna
# Category Embedding Public Services & Government > Department of finance
# Category Embedding Local Services > Swimming pool repair service
# Category Embedding Local Services > Video game rental kiosk
# Category Embedding Education > Massage school
# Category Embedding Local Services > Slaughterhouse
# Category Embedding Home Services > Pool cleaning service
# Category Embedding Professional Services > Tax consultant
# Category Embedding Industrial Goods and Manufacturing > Olive oil bottling company
# Category Embedding Shopping > Surgical products wholesaler
# Category Embedding Local Services > Shipping company
# Category Embedding Education > Religious school
# Category Embedding Industrial Goods and Manufacturing > Toy and game manufacturer
# Category Embedding Restaurants > Crab house
# Category Embedding Food > Food and beverage exporter
# Category Embedding Industrial Goods and Manufacturing > Car manufacturer
# Category Embedding Shopping > Packaging supply store
# Category Embedding Shopping > Trailer repair shop
# Category Embedding Restaurants > Dan Dan noodle restaurant
# Category Embedding Restaurants > Offal barbecue restaurant
# Category Embedding Active Life > Iron works
# Category Embedding Industrial Goods and Manufacturing > Pumping equipment and service
# Category Embedding Public Services & Government > City department of transportation
# Category Embedding Restaurants > Cold noodle restaurant
# Category Embedding Mining & Agriculture > Gold mining company
# Category Embedding Hotels & Travel > Motel
# Category Embedding Home Services > Lawn mower repair service
# Category Embedding Local Services > Blueprint service
# Category Embedding Mining & Agriculture > Seafood farm
# Category Embedding Restaurants > Vegetarian restaurant
# Category Embedding Industrial Goods and Manufacturing > Coffee machine supplier
# Category Embedding Active Life > Tai chi school
# Category Embedding Local Services > Metalware dealer
# Category Embedding Local Services > Luggage storage facility
# Category Embedding Local Services > Greengrocer
# Category Embedding Religious Organizations > United Methodist church
# Category Embedding Mining & Agriculture > Tree farm
# Category Embedding Arts & Entertainment > Public sauna
# Category Embedding Shopping > Popcorn store
# Category Embedding Active Life > Adaptive sports center
# Category Embedding Local Services > Equestrian facility
# Category Embedding Arts & Entertainment > Public parking space
# Category Embedding Restaurants > Peruvian restaurant
# Category Embedding Arts & Entertainment > Amusement park ride
# Category Embedding Home Services > Home insurance agency
# Category Embedding Restaurants > Pempek restaurant
# Category Embedding Automotive > Alfa Romeo dealer
# Category Embedding Local Services > Pile driving service
# Category Embedding Shopping > Souvenir store
# Category Embedding Automotive > Auto painting
# Category Embedding Shopping > Dry wall supply store
# Category Embedding Restaurants > Welsh restaurant
# Category Embedding Local Services > Upholstery shop
# Category Embedding Industrial Goods and Manufacturing > Commercial refrigerator supplier
# Category Embedding Health & Medical > Eye care center
# Category Embedding Food > Barbecue area
# Category Embedding Active Life > Football club
# Category Embedding Restaurants > Seafood restaurant
# Category Embedding Education > General education school
# Category Embedding Professional Services > Forensic consultant
# Category Embedding Local Services > Professional and hobby associations
# Category Embedding Shopping > Judicial auction
# Category Embedding Restaurants > Steamboat restaurant
# Category Embedding Education > High school
# Category Embedding Shopping > Fabric wholesaler
# Category Embedding Restaurants > South Indian restaurant
# Category Embedding Hotels & Travel > Tour agency
# Category Embedding Restaurants > German restaurant
# Category Embedding Industrial Goods and Manufacturing > Tyre manufacturer
# Category Embedding Shopping > Hua gong shop
# Category Embedding Professional Services > Taxidermist
# Category Embedding Automotive > Dealer of Fiat Professional
# Category Embedding Public Services & Government > State social development
# Category Embedding Local Services > Jewelry designer
# Category Embedding Industrial Goods and Manufacturing > Battery wholesaler
# Category Embedding Shopping > Store
# Category Embedding Industrial Goods and Manufacturing > Scale supplier
# Category Embedding Shopping > Seal shop
# Category Embedding Education > Faculty of chemistry
# Category Embedding Automotive > Snowmobile dealer
# Category Embedding Industrial Goods and Manufacturing > Gasket manufacturer
# Category Embedding Food > Hypermarket
# Category Embedding Professional Services > Escrow service
# Category Embedding Public Services & Government > City pillar shrine
# Category Embedding Industrial Goods and Manufacturing > Fertilizer supplier
# Category Embedding Shopping > Picture frame shop
# Category Embedding Health & Medical > Medical office
# Category Embedding Local Services > Astrologer
# Category Embedding Shopping > Sheepskin coat store
# Category Embedding Professional Services > Family law attorney
# Category Embedding Event Planning & Services > Banquet hall
# Category Embedding Home Services > Conservatory construction contractor
# Category Embedding Shopping > Outerwear store
# Category Embedding Shopping > Electric bicycle store
# Category Embedding Religious Organizations > Mennonite church
# Category Embedding Active Life > Paintball center
# Category Embedding Restaurants > Nyonya restaurant
# Category Embedding Shopping > Bedding store
# Category Embedding Financial Services > Trust bank
# Category Embedding Shopping > Qing fang market place
# Category Embedding Industrial Goods and Manufacturing > Meat packer
# Category Embedding Food > Charcuterie
# Category Embedding Mining & Agriculture > Thermal power plant
# Category Embedding Mining & Agriculture > Electrical substation
# Category Embedding Health & Medical > Sleep clinic
# Category Embedding Shopping > Notions store
# Category Embedding Active Life > Municipal Department of Sports
# Category Embedding Nightlife > Gay bar
# Category Embedding Restaurants > Filipino restaurant
# Category Embedding Event Planning & Services > Meeting planning service
# Category Embedding Religious Organizations > Church of Christ
# Category Embedding Public Services & Government > Environment office
# Category Embedding Health & Medical > Gynecologist
# Category Embedding veterinary care
# Category Embedding Arts & Entertainment > Amphitheater
# Category Embedding Hotels & Travel > Travellers lodge
# Category Embedding Health & Medical > Speech pathologist
# Category Embedding Local Services > Office space rental agency
# Category Embedding Restaurants > Raw food restaurant
# Category Embedding Automotive > Boat dealer
# Category Embedding Education > Realschule (middle-tier secondary school)
# Category Embedding Health & Medical > Medical laboratory
# Category Embedding Industrial Goods and Manufacturing > Power plant equipment supplier
# Category Embedding Health & Medical > Pediatric ophthalmologist
# Category Embedding Restaurants > Korean restaurant
# Category Embedding Professional Services > Forestry service
# Category Embedding Shopping > Wholesale market
# Category Embedding Shopping > Kitchen furniture store
# Category Embedding Restaurants > Irish restaurant
# Category Embedding Shopping > Exhibit
# Category Embedding Shopping > Used computer store
# Category Embedding Hotels & Travel > Hot spring hotel
# Category Embedding Health & Medical > Sports medicine physician
# Category Embedding Public Services & Government > Adult day care center
# Category Embedding Education > Cooking class
# Category Embedding Pets > Dog day care center
# Category Embedding Local Services > Casket service
# Category Embedding Health & Medical > Cosmetic surgeon
# Category Embedding Industrial Goods and Manufacturing > Natural stone exporter
# Category Embedding Local Services > Shoe repair shop
# Category Embedding Shopping > FMCG goods wholesaler
# Category Embedding Public Services & Government > River port
# Category Embedding Shopping > Book store
# Category Embedding Local Services > Shared-use commercial kitchen
# Category Embedding Active Life > Sport tour agency
# Category Embedding Restaurants > Greek restaurant
# Category Embedding Professional Services > Design agency
# Category Embedding Religious Organizations > Jain temple
# Category Embedding Restaurants > Mediterranean restaurant
# Category Embedding Local Services > Metalware producer
# Category Embedding Professional Services > Scenography company
# Category Embedding Industrial Goods and Manufacturing > Aircraft maintenance company
# Category Embedding Automotive > Toyota dealer
# Category Embedding Professional Services > Employment attorney
# Category Embedding Local Services > Double glazing installer
# Category Embedding Industrial Goods and Manufacturing > Butane gas supplier
# Category Embedding Shopping > Gun shop
# Category Embedding Shopping > Disposable Nappies
# Category Embedding Active Life > Parkour spot
# Category Embedding Active Life > Skeet shooting range
# Category Embedding Industrial Goods and Manufacturing > Hay supplier
# Category Embedding Professional Services > Conservatory supply & installation
# Category Embedding Industrial Goods and Manufacturing > Metal processing company
# Category Embedding Arts & Entertainment > Aeroclub
# Category Embedding Public Services & Government > Sokol house
# Category Embedding Industrial Goods and Manufacturing > Stone supplier
# Category Embedding Professional Services > Vehicle shipping agent
# Category Embedding Shopping > Hotel supply store
# Category Embedding Public Services & Government > Chamber of agriculture
# Category Embedding Local Services > Shoe shining service
# Category Embedding Financial Services > Mortgage lender
# Category Embedding Industrial Goods and Manufacturing > Mobility equipment supplier
# Category Embedding Restaurants > Sfiha restaurant
# Category Embedding Active Life > Hockey rink
# Category Embedding Transportation > Mailing service
# Category Embedding Restaurants > Soto ayam restaurant
# Category Embedding Restaurants > Indian restaurant
# Category Embedding Restaurants > Shandong restaurant
# Category Embedding Active Life > Netball club
# Category Embedding Shopping > Kebab shop
# Category Embedding Active Life > Rugby
# Category Embedding Shopping > Paper store
# Category Embedding Industrial Goods and Manufacturing > Wind turbine builder
# Category Embedding Shopping > Driveshaft shop
# Category Embedding Education > Music conservatory
# Category Embedding Local Services > Environmental protection organization
# Category Embedding Active Life > Pedestrian zone
# Category Embedding Food > Bagel shop
# Category Embedding Arts & Entertainment > Flamenco theater
# Category Embedding Local Services > Stone cutter
# Category Embedding Home Services > Stair contractor
# Category Embedding Beauty & Spas > Barber shop
# Category Embedding Industrial Goods and Manufacturing > Filtration plant
# Category Embedding Shopping > Shower door shop
# Category Embedding Restaurants > Cafe > Cosplay cafe
# Category Embedding Local Services > Fire protection service
# Category Embedding Restaurants > Pacific Northwest restaurant (Canada)
# Category Embedding Shopping > Italian grocery store
# Category Embedding Local Services > Funeral celebrant service
# Category Embedding Automotive > Aston Martin dealer
# Category Embedding Real Estate > Castle
# Category Embedding Shopping > Belt shop
# Category Embedding Industrial Goods and Manufacturing > Helium gas supplier
# Category Embedding Restaurants > Brasserie
# Category Embedding Professional Services > Estate planning attorney
# Category Embedding Shopping > Medical book store
# Category Embedding Food > Staple food package
# Category Embedding Shopping > Architectural salvage store
# Category Embedding Restaurants > Chinese tea house
# Category Embedding Restaurants > Sweets and dessert buffet
# Category Embedding Automotive > Daihatsu dealer
# Category Embedding Health & Medical > Psychomotor therapist
# Category Embedding Professional Services > Nanotechnology engineering service
# Category Embedding Health & Medical > Dental insurance agency
# Category Embedding Local Services > Snow removal service
# Category Embedding Education > Christian college
# Category Embedding Education > Girls' high school
# Category Embedding Professional Services > Hair replacement service
# Category Embedding Restaurants > Austrian restaurant
# Category Embedding Shopping > Hunting store
# Category Embedding Financial Services > Mobile money agent
# Category Embedding Shopping > Natural goods store
# Category Embedding Active Life > Swimming lake
# Category Embedding Shopping > Oil wholesaler
# Category Embedding Automotive > Renault dealer
# Category Embedding Restaurants > Yakitori restaurant
# Category Embedding Active Life > Volleyball court
# Category Embedding Restaurants > Taiwanese restaurant
# Category Embedding Active Life > Water skiing instructor
# Category Embedding Shopping > Tool repair shop
# Category Embedding Shopping > Cricket shop
# Category Embedding Restaurants > Latin American restaurant
# Category Embedding Local Services > Piano moving service
# Category Embedding Shopping > Photo shop
# Category Embedding Shopping > Game store
# Category Embedding Local Services > Video game rental service
# Category Embedding Professional Services > Fixed-base operator
# Category Embedding Restaurants > Southeast Asian restaurant
# Category Embedding Local Services > Car repair and maintenance service
# Category Embedding Transportation > Driver's license office
# Category Embedding Food > Electronics vending machine
# Category Embedding Local Services > Construction machine rental service
# Category Embedding Shopping > Running store
# Category Embedding Public Services & Government > Provincial council
# Category Embedding Hotels & Travel > Ski resort
# Category Embedding Public Services & Government > Ground self defense force
# Category Embedding Transportation > Compressed natural gas station
# Category Embedding Professional Services > Model design company
# Category Embedding Shopping > Variety store
# Category Embedding Local Services > Agistment service
# Category Embedding Beauty & Spas > Beautician
# Category Embedding Shopping > Beach clothing store
# Category Embedding Mining & Agriculture > Agricultural organization
# Category Embedding Local Services > Telephone answering service
# Category Embedding Restaurants > Piedmontese restaurant
# Category Embedding Active Life > Indoor snowcenter
# Category Embedding Home Services > Stove builder
# Category Embedding Restaurants > Okonomiyaki restaurant
# Category Embedding Transportation > Road safety town
# Category Embedding Health & Medical > Occupational therapist
# Category Embedding Automotive > Mercedes-Benz dealer
# Category Embedding Industrial Goods and Manufacturing > Abrasives supplier
# Category Embedding Education > Primary school
# Category Embedding Industrial Goods and Manufacturing > Fuel supplier
# Category Embedding Active Life > Aikido club
# Category Embedding Home Services > Pressure washing service
# Category Embedding Active Life > Table tennis club
# Category Embedding Restaurants > Takoyaki restaurant
# Category Embedding Local Services > Small appliance repair service
# Category Embedding Local Services > Temp agency
# Category Embedding Education > Higher secondary school
# Category Embedding Shopping > Metal working shop
# Category Embedding Industrial Goods and Manufacturing > Contact lenses supplier
# Category Embedding Local Services > Fortune telling services
# Category Embedding Health & Medical > Pediatric dentist
# Category Embedding Public Services & Government > Library
# Category Embedding Local Services > Vehicle wrapping service
# Category Embedding Home Services > Railroad contractor
# Category Embedding Professional Services > Health counselor
# Category Embedding Hotels & Travel > Onsen
# Category Embedding Education > Senior high school
# Category Embedding Shopping > Transmission shop
# Category Embedding Arts & Entertainment > Wax museum
# Category Embedding Beauty & Spas > Craniosacral therapy
# Category Embedding Automotive > Lexus dealer
# Category Embedding Industrial Goods and Manufacturing > Camper shell supplier
# Category Embedding Education > Vocational school
# Category Embedding Active Life > Aquarium
# Category Embedding Industrial Goods and Manufacturing > Water jet cutting service
# Category Embedding Industrial Goods and Manufacturing > Solar hot water system supplier
# Category Embedding Religious Organizations > Deaf church
# Category Embedding Shopping > Steamed bun shop
# Category Embedding Home Services > Contractor
# Category Embedding Arts & Entertainment > Children's museum
# Category Embedding Restaurants > Pancake restaurant
# Category Embedding Active Life > Water polo pool
# Category Embedding Beauty & Spas > Body piercing shop
# Category Embedding Industrial Goods and Manufacturing > Lighting manufacturer
# Category Embedding Shopping > Shoe store
# Category Embedding Public Services & Government > Economic development agency
# Category Embedding Automotive > Auto broker
# Category Embedding Pets > Pet store
# Category Embedding Local Services > Self service car wash
# Category Embedding Industrial Goods and Manufacturing > Paving materials supplier
# Category Embedding Shopping > Wheel store
# Category Embedding Shopping > Vintage clothing store
# Category Embedding Shopping > Seafood wholesaler
# Category Embedding Hotels & Travel > Serviced apartment
# Category Embedding Restaurants > Wok restaurant
# Category Embedding Local Services > Youth organization
# Category Embedding Shopping > Police supply store
# Category Embedding Shopping > Paint store
# Category Embedding Financial Services > Tax preparation service
# Category Embedding Shopping > Rubber stamp store
# Category Embedding Home Services > Window cleaning service
# Category Embedding Professional Services > Printed music publisher
# Category Embedding Professional Services > Accountant
# Category Embedding Beauty & Spas > Day spa
# Category Embedding Restaurants > Durum restaurant
# Category Embedding Shopping > Clothing wholesaler
# Category Embedding Health & Medical > Otolaryngology clinic
# Category Embedding Nightlife > Girl bar
# Category Embedding Mining & Agriculture > Cattle market
# Category Embedding Local Services > Youth care
# Category Embedding Industrial Goods and Manufacturing > Truss manufacturer
# Category Embedding Industrial Goods and Manufacturing > Desalination plant
# Category Embedding Education > Hardware training institute
# Category Embedding Industrial Goods and Manufacturing > Piano maker
# Category Embedding Industrial Goods and Manufacturing > Automation company
# Category Embedding Local Services > Fraternal organization
# Category Embedding Industrial Goods and Manufacturing > Paper shredding machine supplier
# Category Embedding Industrial Goods and Manufacturing > Photocopiers supplier
# Category Embedding Health & Medical > Tattoo removal service
# Category Embedding Restaurants > Manado restaurant
# Category Embedding Active Life > Park
# Category Embedding Arts & Entertainment > Fishing charter
# Category Embedding Transportation > Mountain cable car
# Category Embedding Restaurants > New England restaurant
# Category Embedding Restaurants > Marathi restaurant
# Category Embedding Restaurants > Caucasian restaurant
# Category Embedding Local Services > Entertainer
# Category Embedding Restaurants > Assamese restaurant
# Category Embedding Active Life > Cricket ground
# Category Embedding Education > Accounting school
# Category Embedding Religious Organizations > Catholic church
# Category Embedding Shopping > Iron ware dealer
# Category Embedding Health & Medical > Oral and maxillofacial surgeon
# Category Embedding Restaurants > Goan restaurant
# Category Embedding Public Services & Government > Regional government office
# Category Embedding Shopping > Curtain store
# Category Embedding Education > Baby swimming school
# Category Embedding Shopping > Air conditioning store
# Category Embedding Active Life > Sailing club
# Category Embedding Arts & Entertainment > Canoeing area
# Category Embedding Automotive > Buick dealer
# Category Embedding Education > Samba school
# Category Embedding Local Services > Toolroom
# Category Embedding Health & Medical > Blood donation center
# Category Embedding Local Services > Notaries association
# Category Embedding Active Life > Freestyle wrestling
# Category Embedding Industrial Goods and Manufacturing > Biotechnology company
# Category Embedding Education > Mathematics school
# Category Embedding Local Services > Memorial estate
# Category Embedding Financial Services > Leasing service
# Category Embedding Religious Organizations > Synagogue
# Category Embedding Industrial Goods and Manufacturing > Mailing machine supplier
# Category Embedding Shopping > Silk store
# Category Embedding Shopping > Airbrushing supply store
# Category Embedding Home Services > Steel framework contractor
# Category Embedding Industrial Goods and Manufacturing > Medical equipment supplier
# Category Embedding Public Services & Government > Post office
# Category Embedding Hotels & Travel > Resort hotel
# Category Embedding Beauty & Spas > Facial spa
# Category Embedding Public Services & Government > Military base
# Category Embedding Shopping > Frozen food store
# Category Embedding Local Services > Lawyers association
# Category Embedding Industrial Goods and Manufacturing > Mold maker
# Category Embedding Education > Aikido school
# Category Embedding Local Services > Corporate office
# Category Embedding Shopping > Dried flower shop
# Category Embedding Local Services > Records storage facility
# Category Embedding Home Services > Gazebo builder
# Category Embedding Arts & Entertainment > Bouncy castle hire
# Category Embedding Education > Planetarium
# Category Embedding Home Services > Appliances customer service
# Category Embedding Shopping > Watch store
# Category Embedding Beauty & Spas > Skin care clinic
# Category Embedding Education > Cramming school
# Category Embedding Public Services & Government > City government office
# Category Embedding Shopping > Novelties wholesaler
# Category Embedding Pets > Pet sitter
# Category Embedding Professional Services > Commercial photographer
# Category Embedding Food > Candy store
# Category Embedding Local Services > Veterans center
# Category Embedding Professional Services > Life coach
# Category Embedding Local Services > Mens tailor
# Category Embedding Hotels & Travel > Country house
# Category Embedding Automotive > Trailer dealer
# Category Embedding Local Services > Public bath
# Category Embedding Education > University
# Category Embedding Industrial Goods and Manufacturing > Machining manufacturer
# Category Embedding Industrial Goods and Manufacturing > Mailbox supplier
# ...
# Category Embedding Restaurants > Brazilian restaurant
# Category Embedding Education > Government college
# Category Embedding Religious Organizations > Hindu temple
# Category Embedding Local Services > Conveyancer
# Category Embedding Restaurants > Shabu-shabu restaurant
# Category Embedding Food > Seafood market
# Category Embedding Food > Supermarket
# Category Embedding Shopping > Home goods store
# Category Embedding Professional Services > Lighting consultant
# Category Embedding Shopping > Used furniture store
# Category Embedding Public Services & Government > Telephone company
# Category Embedding Local Services > Non-profit organization
# Category Embedding Health & Medical > Pharmaceutical company
# Category Embedding Shopping > Hobby store
# Category Embedding Local Services > Meditation center
# Category Embedding Mining & Agriculture > Stable
# Category Embedding Restaurants > Baden restaurant
# Category Embedding Shopping > Handbags shop
# Category Embedding Shopping > Men's clothing store
# Category Embedding Hotels & Travel > Airport shuttle service
# Category Embedding Home Services > Interior construction contractor
# Category Embedding Food > Cured ham warehouse
# Category Embedding Shopping > Off track betting shop
# Category Embedding Education > Single sex secondary school
# Category Embedding Active Life > Childrens club
# Category Embedding Hotels & Travel > Log cabins
# Category Embedding Hotels & Travel > Recreational vehicle rental agency
# Category Embedding Local Services > Carpet cleaning service
# Category Embedding Restaurants > Balinese restaurant
# Category Embedding Shopping > Pen store
# Category Embedding Arts & Entertainment > Art dealer
# Category Embedding Restaurants > Poke bar
# Category Embedding Industrial Goods and Manufacturing > Gravel plant
# Category Embedding Shopping > Soba noodle shop
# Category Embedding Pets > Veterinarian
# Category Embedding Local Services > Salvage yard
# Category Embedding Health & Medical > Rectory
# Category Embedding Shopping > Craft store
# Category Embedding Shopping > Discount store
# Category Embedding Professional Services > Homekill service
# Category Embedding Restaurants > Soto restaurant
# Category Embedding Public Services & Government > Chamber of handicrafts
# Category Embedding Public Services & Government > State department of social defense
# Category Embedding Shopping > Linens store
# Category Embedding Restaurants > Jewish restaurant
# Category Embedding Shopping > Countertop store
# Category Embedding Local Services > Forklift rental service
# Category Embedding Restaurants > Maltese restaurant
# Category Embedding Local Services > Television repair service
# Category Embedding Industrial Goods and Manufacturing > Coffin supplier
# Category Embedding Public Services & Government > State Dept of Sports
# Category Embedding Restaurants > Odia restaurant
# Category Embedding Active Life > Gym
# Category Embedding Industrial Goods and Manufacturing > Metal industry suppliers
# Category Embedding Health & Medical > Medical group
# Category Embedding Professional Services > Mining consultant
# Category Embedding Professional Services > Architects association
# Category Embedding Public Services & Government > Resident registration office
# Category Embedding Shopping > Cane furniture store
# Category Embedding Active Life > Rock climbing gym
# Category Embedding Active Life > Judo club
# Category Embedding Active Life > Tennis club
# Category Embedding Public Services & Government > State office of education
# Category Embedding Local Services > Holiday accommodation service
# Category Embedding Active Life > Skating instructor
# Category Embedding Pets > House sitter agency
# Category Embedding Shopping > Racing car parts store
# Category Embedding Local Services > Curtain and upholstery cleaning service
# Category Embedding Real Estate > Apartment complex
# Category Embedding Local Services > Gasfitter
# Category Embedding Local Services > Physical examination center
# Category Embedding Food > Industrial supermarket
# Category Embedding Public Services & Government > Customs department
# Category Embedding Industrial Goods and Manufacturing > Fur manufacturer
# Category Embedding Restaurants > Fujian restaurant
# Category Embedding Industrial Goods and Manufacturing > Hydraulic equipment supplier
# Category Embedding Health & Medical > TB clinic
# Category Embedding Professional Services > Sculptor
# Category Embedding Education > Truck driving school
# Category Embedding Shopping > Equestrian store
# Category Embedding Professional Services > Blacksmith
# Category Embedding Arts & Entertainment > Art center
# Category Embedding Professional Services > Surveyor
# Category Embedding Industrial Goods and Manufacturing > Carpet manufacturer
# Category Embedding Industrial Goods and Manufacturing > Fish processing
# Category Embedding Arts & Entertainment > Bird watching area
# Category Embedding Hotels & Travel > Retirement community
# Category Embedding Public Services & Government > State government office
# Category Embedding Hotels & Travel > Dude ranch
# Category Embedding Education > Junior college
# Category Embedding Religious Organizations > Parish
# Category Embedding Industrial Goods and Manufacturing > Food products supplier
# Category Embedding Restaurants > Hot dog restaurant
# Category Embedding Local Services > Technical service
# Category Embedding Shopping > Clothes and fabric wholesaler
# Category Embedding Arts & Entertainment > Athletic park
# Category Embedding Shopping > Computer store
# Category Embedding Local Services > Fiberglass repair service
# Category Embedding Professional Services > Geologist
# Category Embedding Restaurants > Biryani restaurant
# Category Embedding Public Services & Government > Social security office
# Category Embedding Local Services > Chimney services
# Category Embedding Financial Services > Public sector bank
# Category Embedding repairs
# Category Embedding Hotels & Travel > Cultural landmark
# Category Embedding Shopping > Toll road rest stop
# Category Embedding Automotive > Used motorcycle dealer
# Category Embedding Professional Services > Tattoo artist
# Category Embedding Shopping > Stationery store
# Category Embedding Public Services & Government > Ministry of Education
# Category Embedding Arts & Entertainment > Band
# Category Embedding Religious Organizations > United Church of Canada
# Category Embedding Shopping > Art supply store
# Category Embedding Industrial Goods and Manufacturing > Anodizing service
# Category Embedding Professional Services > Carpenter
# Category Embedding Financial Services > Investment service
# Category Embedding Nightlife > Cocktail bar
# Category Embedding Shopping > Electronics accessories wholesaler
# Category Embedding Restaurants > Down home cooking restaurant
# Category Embedding Local Services > Building equipment hire service
# Category Embedding Education > Capoeira school
# Category Embedding Shopping > Pie shop
# Category Embedding Professional Services > Earth works company
# Category Embedding Local Services > Telemarketing service
# Category Embedding Food > Butcher shop
# Category Embedding Restaurants > Fast food restaurant
# Category Embedding Industrial Goods and Manufacturing > Oil and gas exploration service
# Category Embedding Active Life > Private golf course
# Category Embedding Home Services > Drilling contractor
# Category Embedding Arts & Entertainment > Business park
# Category Embedding Local Services > Video editing service
# Category Embedding Financial Services > ATM
# Category Embedding Shopping > Lumber store
# Category Embedding Arts & Entertainment > Shogi lesson
# Category Embedding Public Services & Government > Municipal administration office
# Category Embedding Shopping > Windsurfing store
# Category Embedding Home Services > Sewage disposal service
# Category Embedding Active Life > Personal trainer
# Category Embedding Local Services > Repair service
# Category Embedding Shopping > Adult DVD store
# Category Embedding Health & Medical > Gastroenterologist
# Category Embedding Restaurants > Scottish restaurant
# Category Embedding Restaurants > Sukiyaki and Shabu Shabu restaurant
# Category Embedding Health & Medical > STD clinic
# Category Embedding Financial Services > Financial Advisor
# Category Embedding Industrial Goods and Manufacturing > Paper mill
# Category Embedding Shopping > Pharmaceutical products wholesaler
# Category Embedding Industrial Goods and Manufacturing > Stationery manufacturer
# Category Embedding Arts & Entertainment > Hip hop dance class
# Category Embedding Industrial Goods and Manufacturing > Air compressor supplier
# Category Embedding Shopping > Sportswear store
# Category Embedding Restaurants > Bar restaurant furniture store
# Category Embedding Religious Organizations > Unitarian Universalist Church
# Category Embedding Automotive > Indian Motorcycle dealer
# Category Embedding Active Life > Computer club
# Category Embedding Home Services > Railing contractor
# Category Embedding Shopping > Dental supply store
# Category Embedding Shopping > Traditional Kostume store
# Category Embedding Industrial Goods and Manufacturing > Air filter supplier
# Category Embedding Professional Services > Research engineer
# Category Embedding Industrial Goods and Manufacturing > Container supplier
# Category Embedding Local Services > Office equipment rental service
# Category Embedding Local Services > Newsstand
# Category Embedding Restaurants > Tuscan restaurant
# Category Embedding Food > Grocery store
# Category Embedding Home Services > Furnace repair service
# Category Embedding Food > Rest stop
# Category Embedding Local Services > Judicial scrivener
# Category Embedding Hotels & Travel > Space of remembrance
# Category Embedding Active Life > Bowling alley
# Category Embedding Active Life > Hunting club
# Category Embedding Industrial Goods and Manufacturing > Mechanical plant
# Category Embedding Restaurants > Costa Rican restaurant
# Category Embedding Restaurants > Oyster bar restaurant
# Category Embedding Industrial Goods and Manufacturing > EFTPOS equipment supplier
# Category Embedding Restaurants > Bavarian restaurant
# Category Embedding Automotive > DS Automobiles dealer
# Category Embedding Education > Graduate school
# Category Embedding Active Life > Rsl club
# Category Embedding Nightlife > Cured ham bar
# Category Embedding Automotive > Car dealer
# Category Embedding Religious Organizations > Messianic synagogue
# Category Embedding Restaurants > Continental restaurant
# Category Embedding Religious Organizations > Place of worship
# Category Embedding Education > English language school
# Category Embedding Shopping > Butcher shop deli
# Category Embedding Professional Services > Electrical engineer
# Category Embedding Health & Medical > Hyperbaric medicine physician
# Category Embedding Shopping > Confectionery wholesaler
# Category Embedding Mining & Agriculture > Mine
# Category Embedding Education > Ski school
# Category Embedding Health & Medical > Radiologist
# Category Embedding Religious Organizations > Orthodox synagogue
# Category Embedding Professional Services > Land surveying office
# Category Embedding Professional Services > Human resource consulting
# Category Embedding Professional Services > Photo agency
# Category Embedding Education > Private college
# Category Embedding Industrial Goods and Manufacturing > Mill
# Category Embedding Food > Government ration shop
# Category Embedding Health & Medical > Pediatric urologist
# Category Embedding Arts & Entertainment > Gay sauna
# Category Embedding Professional Services > Interior Decorator
# Category Embedding Nightlife > Cider bar
# Category Embedding Arts & Entertainment > Dance company
# Category Embedding Other > Not Supported by Google
# Category Embedding Local Services > Container service
# Category Embedding Industrial Goods and Manufacturing > Stainless steel plant
# Category Embedding Industrial Goods and Manufacturing > Dairy supplier
# Category Embedding Restaurants > Indian sizzler restaurant
# Category Embedding Professional Services > Dating service
# Category Embedding Automotive > Tuning automobile
# Category Embedding Education > Civil examinations academy
# Category Embedding Industrial Goods and Manufacturing > Ventilating equipment manufacturer
# Category Embedding Restaurants > Fish & chips restaurant
# Category Embedding Local Services > Aircraft rental service
# Category Embedding Public Services & Government > Department of Transportation
# Category Embedding Education > Hospitality high school
# Category Embedding Industrial Goods and Manufacturing > Soy sauce maker
# Category Embedding Education > Study at home school
# Category Embedding Professional Services > Chartered accountant
# Category Embedding Home Services > Plumber
# Category Embedding Automotive > Race car dealer
# Category Embedding Local Services > Piano tuning service
# Category Embedding Education > Real estate school
# Category Embedding Transportation > Alternative fuel station
# Category Embedding Food > Chicken hatchery
# Category Embedding Active Life > Court reporter
# Category Embedding Public Services & Government > Land planning authority
# Category Embedding Education > Fire fighters academy
# Category Embedding Shopping > Fur coat shop
# Category Embedding Industrial Goods and Manufacturing > Patio enclosure supplier
# Category Embedding Shopping > Futon store
# Category Embedding Industrial Goods and Manufacturing > Wax supplier
# Category Embedding Automotive > Peugeot dealer
# Category Embedding Financial Services > Bankruptcy service
# Category Embedding Restaurants > Haitian restaurant
# Category Embedding Shopping > Wallpaper store
# Category Embedding Local Services > Phone repair service
# Category Embedding Mining & Agriculture > Soil testing service
# Category Embedding Local Services > VCR repair service
# Category Embedding Active Life > Batting cage center
# Category Embedding Public Services & Government > State Department Civil Defense
# Category Embedding Active Life > Carnival club
# Category Embedding Local Services > Office refurbishment service
# Category Embedding Restaurants > Cambodian restaurant
# Category Embedding Industrial Goods and Manufacturing > Diesel fuel supplier
# Category Embedding Restaurants > Betawi restaurant
# Category Embedding Shopping > Rice cake shop
# Category Embedding Hotels & Travel > Sculpture
# Category Embedding Shopping > DJ supply store
# Category Embedding Restaurants > Soup restaurant
# Category Embedding Local Services > Animal rescue service
# Category Embedding Health & Medical > Neurologist
# Category Embedding Arts & Entertainment > Parasailing ride operator
# Category Embedding Arts & Entertainment > Philharmonic hall
# Category Embedding Public Services & Government > Military board
# Category Embedding Industrial Goods and Manufacturing > Containers supplier
# Category Embedding Event Planning & Services > Event management company
# Category Embedding Professional Services > Law firm
# Category Embedding Professional Services > Auditor
# Category Embedding Restaurants > Batak restaurant
# Category Embedding Automotive > Auto glass repair service
# Category Embedding Industrial Goods and Manufacturing > Railroad ties supplier
# Category Embedding Professional Services > Building inspector
# Category Embedding Restaurants > Mutton barbecue restaurant
# Category Embedding Local Services > Bookmaker
# Category Embedding Shopping > Mineral water wholesaler
# Category Embedding Shopping > Farm shop
# Category Embedding Restaurants > Cafe > Childrens cafe
# Category Embedding Local Services > Orchid grower
# Category Embedding Local Services > 3D printing service
# Category Embedding Other > Online Only
# Category Embedding Shopping > Pottery store
# Category Embedding Local Services > Business networking company
# Category Embedding Education > School house
# Category Embedding Home Services > Impermeabilization service
# Category Embedding Shopping > Wholesale food store
# Category Embedding Arts & Entertainment > History museum
# Category Embedding Industrial Goods and Manufacturing > Tea exporter
# Category Embedding Shopping > Cosmetics wholesaler
# Category Embedding Restaurants > Oaxacan restaurant
# Category Embedding Professional Services > Computer consultant
# Category Embedding Shopping > Plast window store

# %%
matcher(to_vector, from_vector)
# Out:
# Oilseed (except Soybean) Farming
# Dry Pea and Bean Farming
# Oilseed and Grain Combination Farming
# Sugar Beet Farming
# Hay Farming
# Peanut Farming
# Strawberry Farming
# Orange Groves
# Nursery and Tree Production
# Shellfish Farming
# Soil Preparation Planting & Cultivating
# Veterinary Services
# Landscape Architectural Services
# Other Marine Fishing
# Emergency Property Restoration
# Heavy & Civil Engineering Construction
# Foundation Structure & Building Exterior Contractors
# Building Finishing Contractors
# Meat Processing
# Nonchocolate Confectionery Manufacturing
# Roasted Nuts & Peanut Butter Manufacturing
# Bottled Water Manufacturing
# Tortilla Manufacturing
# Apparel Knitting Mills
# Fiber Yarn & Thread Mills
# Cut & Sew Apparel Contractors
# Cut & Sew Apparel-Except Contractors (Mfrs)
# Curtain & Linen Mills
# Cut Stock Resawing Lumber & Planing
# Wood Window & Door Manufacturing
# Wood Kitchen Cabinet & Countertop (Mfrs)
# Wood Preservation
# Showcase Partition Shelving & Locker (Mfrs)
# Plastics Packaging Film & Sheet (Mfrs)
# Greeting Card Publishers
# Support Activities for Printing
# Artificial & Synthetic Fibers & Filaments (Mfrs)
# Cyclic Crude Intermediate/Gum/Wood Chemical (Mfrs)
# Petrochemical Manufacturing
# Oils-Re-Refined (Mfrs)
# Polystyrene Foam Product (Mfrs)
# Urethane & Other Foam Product-Except Polystyrene (Mfrs)
# Flat Glass (Mfrs)
# Iron & Steel Mills & Ferroalloy (Mfrs)
# Secondary Smelting & Alloying-Aluminum
# Communication & Energy Wire (Mfrs)
# Aluminum Foundries-Except Die-Casting
# Nonferrous Metal Foundries-Except Die-Casting
# Cookware Cutlery & Flatware (Mfrs)
# Heavy Gauge Metal Tank (Mfrs)
# Industrial Mold (Mfrs)
# Sawmill Woodworking & Paper Machinery (Mfrs)
# Industrial Machinery (Mfrs)
# Motor Vehicle Gas Engine & Parts (Mfrs)
# Residential Electric Lighting Fixture (Mfrs)
# Printed Circuit-Electronic Assembly (Mfrs)
# Heavy Duty Truck (Mfrs)
# Railroad Rolling Stock (Mfrs)
# Photographic Film Paper Plate Chemical & Copy Toner (Mfrs)
# Jewelry & Silverware (Mfrs)
# Office Supplies-Ex Paper (Mfrs)
# Fabricated Metal Product (Mfrs)
# Doll Toy & Game (Mfrs)
# Short Line Railroads
# Mixed Mode Transit Systems
# Bus & Motor Vehicle Transit Systems
# Land Scenic & Sightseeing Transportation
# Used Household & Office Goods Moving
# Solid Waste Collection
# Waste Collection & Hauling
# General Freight Trucking Long-Distance
# Long-Distance Specialized Freight Trucking
# Local Specialized Freight Trucking
# Port & Harbor Operations
# Shipping Navigational Services
# Nonscheduled Passenger Air Transportation
# Specialty Nonscheduled Air Transportation
# Misc Road Transportation Support
# Support Activities for Transportation
# Wireless Telecommunications Carriers-Ex Satellite
# Wired Telecommunications Carriers
# Agents for Wireless Telecommunications Services
# Satellite Telecommunications
# Nuclear Electric Power Generation
# Solar Electric Power Generation
# Wind Electric Power Generation
# Geothermal Electric Power Generation
# Biomass Electric Power Generation
# Electric Bulk Power Transmission & Control
# Fossil Fuel Electric Power Generation
# Other Electric Power Generation
# Water Supply & Irrigation Systems
# Solid Waste Combustors & Incinerators
# Nonhazardous Waste Treatment & Disposal
# Materials Recovery Facilities
# Remediation Services
# Automobile & Other Motor Vehicle (Whls)
# Tire & Tube (Whls)
# Brick Stone & Related Const Material (Whls)
# Roofing Siding & Insulation Material (Whls)
# Building Material Dealers
# Computer & Peripheral Eqpt & Software (Whls)
# Medical/Dental/Hospital Eqpt & Supl (Whls)
# Household Appliances & Electronics (Whls)
# Plumbing & Heating Equipment & Supplies (Whls)
# Heating & Air-Cond Eqpt & Supplies (Whls)
# Farm/Garden Machinery & Eqpt (Whls)
# Toy & Hobby Goods & Supplies (Whls)
# Jewelry/Watch Precious Stone & Metal (Whls)
# Printing & Writing Paper (Whls)
# Stationery & Office Supplies (Whls)
# Piece Goods Notions & Other Dry Goods (Whls)
# Footwear (Whls)
# Grain & Field Bean (Whls)
# Wine & Distilled Alcoholic Beverage (Whls)
# Book Periodical & Newspaper (Whls)
# Flower/Nursery Stock/Florists' Supplies (Whls)
# Tobacco Product & Electronic Cigarette (Whls)
# Paint Varnish & Supplies (Whls)
# Paint & Wallpaper Retailers
# Garden Center & Farm Supply Retailers
# Grocers-Delicatessen
# Fish & Seafood Retailers
# Confectionery & Nut Retailers
# Baked Goods Off-site Retailers
# Snack & Nonalcoholic Beverage Bars
# Automobile Dealers-Hydrogen Cars-New
# Book Retailers & News Dealers
# Hobby Toy & Game Retailers
# Luggage & Leather Goods Retailers
# Sewing Needlework & Piece Goods Retailers
# Cannabis Dispensary
# ITM-Interactive Teller Machine
# Peer to Peer Payment Services
# Virtual Currency Brokering & Dealing Exchange Services
# Credit Card Issuing
# Credit Intermediation
# Sales Financing
# Virtual Currency Trading Exchange Clearinghouses
# Health & Welfare Funds
# Reinsurance Carriers
# Residential Property Managers
# Insurance Funds
# Recreational Goods Rental
# Personal & Household Goods Repair & Maintenance
# Personal Care Services NEC
# Home Health Equipment Rental
# Misc Consumer Goods Rental
# Professional Employer Organizations
# Virtual Currency Mining
# Truck Utility Trailer & RV Rental & Leasing
# Specialized Automotive Repair
# Teleproduction & Postproduction Services
# Agents & Managers-Artists Athletes Entertainers
# Theater Companies & Dinner Theaters
# Promoters of Events with Facilities
# Performing Arts Companies
# Spectator Sports
# Freestanding Ambulatory Surgical & Emergency Centers
# Family Planning Centers
# Rehabilitation Services
# Ambulatory Health Care Services
# Cosmetology & Barber Schools
# Fine Arts Schools
# Exam Preparation & Tutoring
# Miscellaneous Schools & Instruction
# Elderly & Disabled Person Services
# Voluntary Health Organizations
# Grantmaking & Giving Services
# Social Membership Organization
# Artificial Intelligence Research/Development
# Nanotechnology Research & Development
# Physical Engineering & Life Sciences Research & Development
# Social Sciences & Humanities Research & Development
# Testing Laboratories & Services
# Administrative & General Management Consulting Services
# Independent Artists Writers & Performers
# Government Executive Offices
# Executive & Legislative Offices Combined
# General Government Support
# Legal Counsel & Prosecution
# Correctional Institutions
# General Justice Public Order & Safety Activities
# Public Finance Activities
# Government Education Programs Administration
# Public Health Programs Administration
# Government Human Resource Programs Administration
# Veterans' Affairs Administration
# Air/Water Resource/Solid Waste Mgmt Programs Administration
# Government Conservation Programs Administration
# Government Housing Programs Administration
# Government Urban Planning/Community/Rural Development Administration
# Government Economic Programs Administration
# Government Regulation & Administration-Communication/Utilities
# Government Agricultural Marketing & Commodities Regulation
# Government Commercial Licensing & Inspection Regulation
# Space Research & Technology
# International Affairs
